# %% [markdown]
# <a href="https://colab.research.google.com/github/mintseok/mnist_skku/blob/main/%EC%9D%B8%EC%A7%80%EC%88%98_MNIST_GD_%EC%86%A1%EC%A7%84%ED%98%B8_%ED%97%88%EB%AF%BC%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/RoadoneP/Deep_Learning_From_Scratch/blob/main/4%EC%9E%A5.ipynb

# %% [markdown]
# 길한 형님의 깃허브에서 Deep Learning From Scratch 따라가기

# %%
from mnist import load_mnist

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=False)

print(x_train.shape) # (60000, 784)
print(t_train.shape) # (60000, 10)
print(x_test.shape)  # (10000, 784)
print(t_test.shape)  # (10000, 10)
print(t_train[0])
# Out:
# Downloading train-images-idx3-ubyte.gz ...
# Done
# Downloading train-labels-idx1-ubyte.gz ...
# Done
# Downloading t10k-images-idx3-ubyte.gz ...
# Done
# Downloading t10k-labels-idx1-ubyte.gz ...
# Done
# Converting train-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting train-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Creating pickle file ...
# Done!
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
# 5

# %%
t_train0 = [] # 5923 -> 300으로 줄여야 한다
t_train1 = [] # 6742 -> 300
t_train2 = [] # 5958
t_train3 = [] # 6131
t_train4 = [] # 5842
t_train5 = [] # 5421
t_train6 = [] # 5918
t_train7 = [] # 6265
t_train8 = [] # 5851
t_train9 = [] # 5949
for i in range(60000):
  if t_train[i]==0:
    t_train0.append(i)
  if t_train[i]==1:
    t_train1.append(i)
  if t_train[i]==2:
    t_train2.append(i)
  if t_train[i]==3:
    t_train3.append(i)
  if t_train[i]==4:
    t_train4.append(i)
  if t_train[i]==5:
    t_train5.append(i)
  if t_train[i]==6:
    t_train6.append(i)
  if t_train[i]==7:
    t_train7.append(i)
  if t_train[i]==8:
    t_train8.append(i)
  if t_train[i]==9:
    t_train9.append(i)

print(len(t_train0), len(t_train1), len(t_train2), len(t_train3), len(t_train4), len(t_train5), len(t_train6), len(t_train7), len(t_train8), len(t_train9))
# Out:
# 5923 6742 5958 6131 5842 5421 5918 6265 5851 5949

# %%
t_test0 = [] # 980 -> 50으로 줄여야 한다
t_test1 = [] # 1135 -> 50
t_test2 = [] # 1032
t_test3 = [] # 1010
t_test4 = [] # 982
t_test5 = [] # 892
t_test6 = [] # 958
t_test7 = [] # 1028
t_test8 = [] # 974
t_test9 = [] # 1009
for i in range(10000):
  if t_test[i]==0:
    t_test0.append(i)
  if t_test[i]==1:
    t_test1.append(i)
  if t_test[i]==2:
    t_test2.append(i)
  if t_test[i]==3:
    t_test3.append(i)
  if t_test[i]==4:
    t_test4.append(i)
  if t_test[i]==5:
    t_test5.append(i)
  if t_test[i]==6:
    t_test6.append(i)
  if t_test[i]==7:
    t_test7.append(i)
  if t_test[i]==8:
    t_test8.append(i)
  if t_test[i]==9:
    t_test9.append(i)

print(len(t_test0), len(t_test1), len(t_test2), len(t_test3), len(t_test4), len(t_test5), len(t_test6), len(t_test7), len(t_test8), len(t_test9))
# Out:
# 980 1135 1032 1010 982 892 958 1028 974 1009

# %%
new_x_train = []
new_t_train = []
RANGE = 250
# 0~7 -> 250개
# 8   -> 600개
# 9   -> 400개
for i in range(RANGE):
  new_t_train.append(t_train[t_train0[i]])
  new_x_train.append(x_train[t_train0[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train1[i]])
  new_x_train.append(x_train[t_train1[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train2[i]])
  new_x_train.append(x_train[t_train2[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train3[i]])
  new_x_train.append(x_train[t_train3[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train4[i]])
  new_x_train.append(x_train[t_train4[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train5[i]])
  new_x_train.append(x_train[t_train5[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train6[i]])
  new_x_train.append(x_train[t_train6[i]])
for i in range(RANGE):
  new_t_train.append(t_train[t_train7[i]])
  new_x_train.append(x_train[t_train7[i]])
for i in range(600):
  new_t_train.append(t_train[t_train8[i]])
  new_x_train.append(x_train[t_train8[i]])
for i in range(400):
  new_t_train.append(t_train[t_train9[i]])
  new_x_train.append(x_train[t_train9[i]])

# %%
new_x_test = []
new_t_test = []
RANGE = 50
for i in range(RANGE):
  new_t_test.append(t_test[t_test0[i]])
  new_x_test.append(x_test[t_test0[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test1[i]])
  new_x_test.append(x_test[t_test1[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test2[i]])
  new_x_test.append(x_test[t_test2[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test3[i]])
  new_x_test.append(x_test[t_test3[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test4[i]])
  new_x_test.append(x_test[t_test4[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test5[i]])
  new_x_test.append(x_test[t_test5[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test6[i]])
  new_x_test.append(x_test[t_test6[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test7[i]])
  new_x_test.append(x_test[t_test7[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test8[i]])
  new_x_test.append(x_test[t_test8[i]])
for i in range(RANGE):
  new_t_test.append(t_test[t_test9[i]])
  new_x_test.append(x_test[t_test9[i]])

# %%
testIdx = []
for i in range(300*10):
  if new_t_train[i] == 8:
    new_t_train[i] = 1
    print(i, end=' ')
  else:
    new_t_train[i] = -1
for i in range(50*10):
  if new_t_test[i] == 8:
    new_t_test[i] = 1
  else:
    new_t_test[i] = -1
# Out:
# 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059 2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073 2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087 2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100 2101 2102 2103 2104 2105 2106 2107 2108 2109 2110 2111 2112 2113 2114 2115 2116 2117 2118 2119 2120 2121 2122 2123 2124 2125 2126 2127 2128 2129 2130 2131 2132 2133 2134 2135 2136 2137 2138 2139 2140 2141 2142 2143 2144 2145 2146 2147 2148 2149 2150 2151 2152 2153 2154 2155 2156 2157 2158 2159 2160 2161 2162 2163 2164 2165 2166 2167 2168 2169 2170 2171 2172 2173 2174 2175 2176 2177 2178 2179 2180 2181 2182 2183 2184 2185 2186 2187 2188 2189 2190 2191 2192 2193 2194 2195 2196 2197 2198 2199 2200 2201 2202 2203 2204 2205 2206 2207 2208 2209 2210 2211 2212 2213 2214 2215 2216 2217 2218 2219 2220 2221 2222 2223 2224 2225 2226 2227 2228 2229 2230 2231 2232 2233 2234 2235 2236 2237 2238 2239 2240 2241 2242 2243 2244 2245 2246 2247 2248 2249 2250 2251 2252 2253 2254 2255 2256 2257 2258 2259 2260 2261 2262 2263 2264 2265 2266 2267 2268 2269 2270 2271 2272 2273 2274 2275 2276 2277 2278 2279 2280 2281 2282 2283 2284 2285 2286 2287 2288 2289 2290 2291 2292 2293 2294 2295 2296 2297 2298 2299 2300 2301 2302 2303 2304 2305 2306 2307 2308 2309 2310 2311 2312 2313 2314 2315 2316 2317 2318 2319 2320 2321 2322 2323 2324 2325 2326 2327 2328 2329 2330 2331 2332 2333 2334 2335 2336 2337 2338 2339 2340 2341 2342 2343 2344 2345 2346 2347 2348 2349 2350 2351 2352 2353 2354 2355 2356 2357 2358 2359 2360 2361 2362 2363 2364 2365 2366 2367 2368 2369 2370 2371 2372 2373 2374 2375 2376 2377 2378 2379 2380 2381 2382 2383 2384 2385 2386 2387 2388 2389 2390 2391 2392 2393 2394 2395 2396 2397 2398 2399 2400 2401 2402 2403 2404 2405 2406 2407 2408 2409 2410 2411 2412 2413 2414 2415 2416 2417 2418 2419 2420 2421 2422 2423 2424 2425 2426 2427 2428 2429 2430 2431 2432 2433 2434 2435 2436 2437 2438 2439 2440 2441 2442 2443 2444 2445 2446 2447 2448 2449 2450 2451 2452 2453 2454 2455 2456 2457 2458 2459 2460 2461 2462 2463 2464 2465 2466 2467 2468 2469 2470 2471 2472 2473 2474 2475 2476 2477 2478 2479 2480 2481 2482 2483 2484 2485 2486 2487 2488 2489 2490 2491 2492 2493 2494 2495 2496 2497 2498 2499 2500 2501 2502 2503 2504 2505 2506 2507 2508 2509 2510 2511 2512 2513 2514 2515 2516 2517 2518 2519 2520 2521 2522 2523 2524 2525 2526 2527 2528 2529 2530 2531 2532 2533 2534 2535 2536 2537 2538 2539 2540 2541 2542 2543 2544 2545 2546 2547 2548 2549 2550 2551 2552 2553 2554 2555 2556 2557 2558 2559 2560 2561 2562 2563 2564 2565 2566 2567 2568 2569 2570 2571 2572 2573 2574 2575 2576 2577 2578 2579 2580 2581 2582 2583 2584 2585 2586 2587 2588 2589 2590 2591 2592 2593 2594 2595 2596 2597 2598 2599

# %%
import numpy as np
x_train = np.array(new_x_train)
x_test = np.array(new_x_test)
t_train = np.array(new_t_train)
t_test = np.array(new_t_test)
print(t_train[0])
print(t_train[2001])

def _change_ont_hot_label(X):
    T = np.zeros((X.size, 1))
    for idx, row in enumerate(T):
        if X[idx]==-1:
          row[0]=-1
        else:
          row[0]=1
        
    return T

t_train = _change_ont_hot_label(t_train)
t_test = _change_ont_hot_label(t_test)

print(t_train[0])
print(t_train[2001])
print(len(x_train))
print(len(t_train))
print(len(x_test))
print(len(t_test))
# Out:
# -1
# 1
# [-1.]
# [1.]
# 3000
# 3000
# 500
# 500

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_diff(x):
    return sigmoid(x) * (1 - sigmoid(x))
    
def softplus(x):
    return np.log(1+np.exp(x))

def softmax(x):
    if x.ndim == 2:
        x = x.T
        x = x - np.max(x, axis=0)
        y = np.exp(x) / np.sum(np.exp(x), axis=0)
        return y.T 

    x = x - np.max(x) # 오버플로 대책
    return np.exp(x) / np.sum(np.exp(x))

def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
        
    # 훈련 데이터가 원-핫 벡터라면 정답 레이블의 인덱스로 반환
    if t.size == y.size:
        t = t.argmax(axis=1)
             
    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t])) / batch_size

def numerical_gradient(f, x):
    h = 1e-4 # 0.0001
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + h
        fxh1 = f(x) # f(x+h)
        
        x[idx] = tmp_val - h 
        fxh2 = f(x) # f(x-h)
        grad[idx] = (fxh1 - fxh2) / (2*h)
        
        x[idx] = tmp_val # 값 복원
        it.iternext()   
        
    return grad

class Relu:
    def __init__(self):
        self.mask = None
    
    def forward(self, x):
        self.mask = (x <= 0)
        out = x.copy()
        out[self.mask] = 0
        
        return out
        
    def backward(self, dout):
        dout[self.mask] = 0
        dx = dout
        
        return dx

class Sigmoid:
    def __init__(self):
        self.out = None
    
    def forward(self, x):
        out = 1 / (1 + np.exp(-x))
        self.out = out
        
        return out
        
    def backward(self, dout):
        dx = dout * (1.0 - self.out) * self.out
        
        return dx

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# 4.2.2. 교차 엔트로피 오차 참고
def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
        
    # 훈련 데이터가 원-핫 벡터라면 정답 레이블의 인덱스로 반환
    if t.size == y.size:
        t = t.argmax(axis=1)
             
    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t])) / batch_size

class SoftmaxWithLoss:
    def __init__(self):
        self.loss = None # 손실
        self.y = None    # softmax의 출력
        self.t = None    # 정답 레이블(원-핫 벡터)
    
    def forward(self, x, t):
        self.t = t
        self.y = softmax(x)
        self.loss = cross_entropy_error(self.y, self.t)
        return self.loss
    
    def backward(self, dout=1):
        batch_size = self.t.shape[0]
        dx = (self.y - self.t) / batch_size
        
        return dx

# %%
class Affine:
    def __init__(self, W, b):
        self.W = W
        self.b = b
        self.x = None
        self.dW = None
        self.db = None
    
    def forward(self, x):
        self.x = x
        out = np.dot(x, self.W) + self.b
                
        return out
    
    def backward(self, dout):
        dx = np.dot(dout, self.W.T)
        repeat = self.x.T.shape[1]
        dout1 = np.repeat(dout, repeat, axis=0)
        self.dW = np.dot(self.x.T, dout1)
        self.db = np.sum(dout, axis=0)
        
        return dx

# %%
def softplus(x):
    return np.log(1+np.exp(x))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softplus_error(y, t):
    if y.ndim == 1:
      t = t.reshape(1, t.size)
      y = y.reshape(1, y.size)
          
    batch_size = y.shape[0]
    return np.sum(np.log(1+np.exp(-np.dot(t.T,y)))) / batch_size

class SoftplusWithLoss:
  def __init__(self):
    self.loss = None # 손실
    self.y = None    # softmax의 출력
    self.t = None    # 정답 레이블(원-핫 벡터)

  def forward(self, x, t):
    self.t = t
    self.y = x # affine 계층에서 들어온 그 값
    self.loss = softplus_error(self.y, self.t)
    return self.loss

  def backward(self, dout=1):
    batch_size = self.t.shape[0]
    dx = (1 - sigmoid(np.dot(self.t.T,self.y))) / batch_size
    
    return dx

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
from collections import OrderedDict

class OneLayerNet:
    def __init__(self, input_size, output_size,weight_init_std=0.01):
        # 가중치 초기화
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, output_size)
        self.params['b1'] = np.zeros(output_size)
        

        # 계층 생성
        self.layers = OrderedDict()
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.lastLayer = SoftplusWithLoss() ###

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)

        return x

    # x : 입력 데이터, t : 정답 레이블
    def loss(self, x, t):
        y = self.predict(x)
        return self.lastLayer.forward(y, t)

    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if t.ndim != 1:
            t = np.argmax(t, axis=1)

        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy

    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])

        return grads

    def gradient(self, x, t):
        # 순전파
        self.loss(x, t)

        # 역전파
        dout = 1
        dout = self.lastLayer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 결과 저장
        grads = {}
        grads['W1'] = self.layers['Affine1'].dW
        grads['b1'] = self.layers['Affine1'].db

        return grads

# %%
net = OneLayerNet(input_size=784,output_size=1)
print(net.params['W1'].shape) # (784, 2)
print(net.params['b1'].shape) # (1,)
# Out:
# (784, 1)
# (1,)

# %%
network = OneLayerNet(input_size=784, output_size=1)
optimizer = SGD() ###

# 하이퍼파라미터
iters_num = 500  # 반복 횟수를 적절히 설정한다.
train_size = x_train.shape[0]
batch_size = 3000   # 미니배치 크기
learning_rate = 0.1
# epsilon = 0.00000001 # 최소 정확도

train_loss_list = []
train_acc_list = []
test_acc_list = []

# 1에폭당 반복 수
iter_per_epoch = max(train_size / batch_size, 1)
print(train_size, batch_size, iter_per_epoch)

for i in range(iters_num):
    # 미니배치 획득
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    #print(x_batch.shape, t_batch.shape)
    
    # 기울기 계산
    #grad = network.numerical_gradient(x_batch, t_batch)
    grads = network.gradient(x_batch, t_batch)
    params = network.params
    optimizer.update(params, grads)
    
    # 학습 경과 기록
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    # 1에폭당 정확도 계산
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        print(str(i)+ ": train acc, test acc | " + str(train_acc) + ", " + str(test_acc))

    # if train_acc>1-epsilon:
    #   break
# Out:
# 3000 3000 1.0
# 0: train acc, test acc | 1.0, 1.0
# 1: train acc, test acc | 1.0, 1.0
# 2: train acc, test acc | 1.0, 1.0
# 3: train acc, test acc | 1.0, 1.0
# 4: train acc, test acc | 1.0, 1.0
# 5: train acc, test acc | 1.0, 1.0
# 6: train acc, test acc | 1.0, 1.0
# 7: train acc, test acc | 1.0, 1.0
# 8: train acc, test acc | 1.0, 1.0
# 9: train acc, test acc | 1.0, 1.0
# 10: train acc, test acc | 1.0, 1.0
# 11: train acc, test acc | 1.0, 1.0
# 12: train acc, test acc | 1.0, 1.0
# 13: train acc, test acc | 1.0, 1.0
# 14: train acc, test acc | 1.0, 1.0
# 15: train acc, test acc | 1.0, 1.0
# 16: train acc, test acc | 1.0, 1.0
# 17: train acc, test acc | 1.0, 1.0
# 18: train acc, test acc | 1.0, 1.0
# 19: train acc, test acc | 1.0, 1.0
# 20: train acc, test acc | 1.0, 1.0
# 21: train acc, test acc | 1.0, 1.0
# 22: train acc, test acc | 1.0, 1.0
# 23: train acc, test acc | 1.0, 1.0
# 24: train acc, test acc | 1.0, 1.0
# 25: train acc, test acc | 1.0, 1.0
# 26: train acc, test acc | 1.0, 1.0
# 27: train acc, test acc | 1.0, 1.0
# 28: train acc, test acc | 1.0, 1.0
# 29: train acc, test acc | 1.0, 1.0
# 30: train acc, test acc | 1.0, 1.0
# 31: train acc, test acc | 1.0, 1.0
# 32: train acc, test acc | 1.0, 1.0
# 33: train acc, test acc | 1.0, 1.0
# 34: train acc, test acc | 1.0, 1.0
# 35: train acc, test acc | 1.0, 1.0
# 36: train acc, test acc | 1.0, 1.0
# 37: train acc, test acc | 1.0, 1.0
# 38: train acc, test acc | 1.0, 1.0
# 39: train acc, test acc | 1.0, 1.0
# 40: train acc, test acc | 1.0, 1.0
# 41: train acc, test acc | 1.0, 1.0
# 42: train acc, test acc | 1.0, 1.0
# 43: train acc, test acc | 1.0, 1.0
# 44: train acc, test acc | 1.0, 1.0
# 45: train acc, test acc | 1.0, 1.0
# 46: train acc, test acc | 1.0, 1.0
# 47: train acc, test acc | 1.0, 1.0
# 48: train acc, test acc | 1.0, 1.0
# 49: train acc, test acc | 1.0, 1.0
# 50: train acc, test acc | 1.0, 1.0
# 51: train acc, test acc | 1.0, 1.0
# 52: train acc, test acc | 1.0, 1.0
# 53: train acc, test acc | 1.0, 1.0
# 54: train acc, test acc | 1.0, 1.0
# 55: train acc, test acc | 1.0, 1.0
# 56: train acc, test acc | 1.0, 1.0
# 57: train acc, test acc | 1.0, 1.0
# 58: train acc, test acc | 1.0, 1.0
# 59: train acc, test acc | 1.0, 1.0
# 60: train acc, test acc | 1.0, 1.0
# 61: train acc, test acc | 1.0, 1.0
# 62: train acc, test acc | 1.0, 1.0
# 63: train acc, test acc | 1.0, 1.0
# 64: train acc, test acc | 1.0, 1.0
# 65: train acc, test acc | 1.0, 1.0
# 66: train acc, test acc | 1.0, 1.0
# 67: train acc, test acc | 1.0, 1.0
# 68: train acc, test acc | 1.0, 1.0
# 69: train acc, test acc | 1.0, 1.0
# 70: train acc, test acc | 1.0, 1.0
# 71: train acc, test acc | 1.0, 1.0
# 72: train acc, test acc | 1.0, 1.0
# 73: train acc, test acc | 1.0, 1.0
# 74: train acc, test acc | 1.0, 1.0
# 75: train acc, test acc | 1.0, 1.0
# 76: train acc, test acc | 1.0, 1.0
# 77: train acc, test acc | 1.0, 1.0
# 78: train acc, test acc | 1.0, 1.0
# 79: train acc, test acc | 1.0, 1.0
# 80: train acc, test acc | 1.0, 1.0
# 81: train acc, test acc | 1.0, 1.0
# 82: train acc, test acc | 1.0, 1.0
# 83: train acc, test acc | 1.0, 1.0
# 84: train acc, test acc | 1.0, 1.0
# 85: train acc, test acc | 1.0, 1.0
# 86: train acc, test acc | 1.0, 1.0
# 87: train acc, test acc | 1.0, 1.0
# 88: train acc, test acc | 1.0, 1.0
# 89: train acc, test acc | 1.0, 1.0
# 90: train acc, test acc | 1.0, 1.0
# 91: train acc, test acc | 1.0, 1.0
# 92: train acc, test acc | 1.0, 1.0
# 93: train acc, test acc | 1.0, 1.0
# 94: train acc, test acc | 1.0, 1.0
# 95: train acc, test acc | 1.0, 1.0
# 96: train acc, test acc | 1.0, 1.0
# 97: train acc, test acc | 1.0, 1.0
# 98: train acc, test acc | 1.0, 1.0
# 99: train acc, test acc | 1.0, 1.0
# 100: train acc, test acc | 1.0, 1.0
# 101: train acc, test acc | 1.0, 1.0
# 102: train acc, test acc | 1.0, 1.0
# 103: train acc, test acc | 1.0, 1.0
# 104: train acc, test acc | 1.0, 1.0
# 105: train acc, test acc | 1.0, 1.0
# 106: train acc, test acc | 1.0, 1.0
# 107: train acc, test acc | 1.0, 1.0
# 108: train acc, test acc | 1.0, 1.0
# 109: train acc, test acc | 1.0, 1.0
# 110: train acc, test acc | 1.0, 1.0
# 111: train acc, test acc | 1.0, 1.0
# 112: train acc, test acc | 1.0, 1.0
# 113: train acc, test acc | 1.0, 1.0
# 114: train acc, test acc | 1.0, 1.0
# 115: train acc, test acc | 1.0, 1.0
# 116: train acc, test acc | 1.0, 1.0
# 117: train acc, test acc | 1.0, 1.0
# 118: train acc, test acc | 1.0, 1.0
# 119: train acc, test acc | 1.0, 1.0
# 120: train acc, test acc | 1.0, 1.0
# 121: train acc, test acc | 1.0, 1.0
# 122: train acc, test acc | 1.0, 1.0
# 123: train acc, test acc | 1.0, 1.0
# 124: train acc, test acc | 1.0, 1.0
# 125: train acc, test acc | 1.0, 1.0
# 126: train acc, test acc | 1.0, 1.0
# 127: train acc, test acc | 1.0, 1.0
# 128: train acc, test acc | 1.0, 1.0
# 129: train acc, test acc | 1.0, 1.0
# 130: train acc, test acc | 1.0, 1.0
# 131: train acc, test acc | 1.0, 1.0
# 132: train acc, test acc | 1.0, 1.0
# 133: train acc, test acc | 1.0, 1.0
# 134: train acc, test acc | 1.0, 1.0
# 135: train acc, test acc | 1.0, 1.0
# 136: train acc, test acc | 1.0, 1.0
# 137: train acc, test acc | 1.0, 1.0
# 138: train acc, test acc | 1.0, 1.0
# 139: train acc, test acc | 1.0, 1.0
# 140: train acc, test acc | 1.0, 1.0
# 141: train acc, test acc | 1.0, 1.0
# 142: train acc, test acc | 1.0, 1.0
# 143: train acc, test acc | 1.0, 1.0
# 144: train acc, test acc | 1.0, 1.0
# 145: train acc, test acc | 1.0, 1.0
# 146: train acc, test acc | 1.0, 1.0
# 147: train acc, test acc | 1.0, 1.0
# 148: train acc, test acc | 1.0, 1.0
# 149: train acc, test acc | 1.0, 1.0
# 150: train acc, test acc | 1.0, 1.0
# 151: train acc, test acc | 1.0, 1.0
# 152: train acc, test acc | 1.0, 1.0
# 153: train acc, test acc | 1.0, 1.0
# 154: train acc, test acc | 1.0, 1.0
# 155: train acc, test acc | 1.0, 1.0
# 156: train acc, test acc | 1.0, 1.0
# 157: train acc, test acc | 1.0, 1.0
# 158: train acc, test acc | 1.0, 1.0
# 159: train acc, test acc | 1.0, 1.0
# 160: train acc, test acc | 1.0, 1.0
# 161: train acc, test acc | 1.0, 1.0
# 162: train acc, test acc | 1.0, 1.0
# 163: train acc, test acc | 1.0, 1.0
# 164: train acc, test acc | 1.0, 1.0
# 165: train acc, test acc | 1.0, 1.0
# 166: train acc, test acc | 1.0, 1.0
# 167: train acc, test acc | 1.0, 1.0
# 168: train acc, test acc | 1.0, 1.0
# 169: train acc, test acc | 1.0, 1.0
# 170: train acc, test acc | 1.0, 1.0
# 171: train acc, test acc | 1.0, 1.0
# 172: train acc, test acc | 1.0, 1.0
# 173: train acc, test acc | 1.0, 1.0
# 174: train acc, test acc | 1.0, 1.0
# 175: train acc, test acc | 1.0, 1.0
# 176: train acc, test acc | 1.0, 1.0
# 177: train acc, test acc | 1.0, 1.0
# 178: train acc, test acc | 1.0, 1.0
# 179: train acc, test acc | 1.0, 1.0
# 180: train acc, test acc | 1.0, 1.0
# 181: train acc, test acc | 1.0, 1.0
# 182: train acc, test acc | 1.0, 1.0
# 183: train acc, test acc | 1.0, 1.0
# 184: train acc, test acc | 1.0, 1.0
# 185: train acc, test acc | 1.0, 1.0
# 186: train acc, test acc | 1.0, 1.0
# 187: train acc, test acc | 1.0, 1.0
# 188: train acc, test acc | 1.0, 1.0
# 189: train acc, test acc | 1.0, 1.0
# 190: train acc, test acc | 1.0, 1.0
# 191: train acc, test acc | 1.0, 1.0
# 192: train acc, test acc | 1.0, 1.0
# 193: train acc, test acc | 1.0, 1.0
# 194: train acc, test acc | 1.0, 1.0
# 195: train acc, test acc | 1.0, 1.0
# 196: train acc, test acc | 1.0, 1.0
# 197: train acc, test acc | 1.0, 1.0
# 198: train acc, test acc | 1.0, 1.0
# 199: train acc, test acc | 1.0, 1.0
# 200: train acc, test acc | 1.0, 1.0
# 201: train acc, test acc | 1.0, 1.0
# 202: train acc, test acc | 1.0, 1.0
# 203: train acc, test acc | 1.0, 1.0
# 204: train acc, test acc | 1.0, 1.0
# 205: train acc, test acc | 1.0, 1.0
# 206: train acc, test acc | 1.0, 1.0
# 207: train acc, test acc | 1.0, 1.0
# 208: train acc, test acc | 1.0, 1.0
# 209: train acc, test acc | 1.0, 1.0
# 210: train acc, test acc | 1.0, 1.0
# 211: train acc, test acc | 1.0, 1.0
# 212: train acc, test acc | 1.0, 1.0
# 213: train acc, test acc | 1.0, 1.0
# 214: train acc, test acc | 1.0, 1.0
# 215: train acc, test acc | 1.0, 1.0
# 216: train acc, test acc | 1.0, 1.0
# 217: train acc, test acc | 1.0, 1.0
# 218: train acc, test acc | 1.0, 1.0
# 219: train acc, test acc | 1.0, 1.0
# 220: train acc, test acc | 1.0, 1.0
# 221: train acc, test acc | 1.0, 1.0
# 222: train acc, test acc | 1.0, 1.0
# 223: train acc, test acc | 1.0, 1.0
# 224: train acc, test acc | 1.0, 1.0
# 225: train acc, test acc | 1.0, 1.0
# 226: train acc, test acc | 1.0, 1.0
# 227: train acc, test acc | 1.0, 1.0
# 228: train acc, test acc | 1.0, 1.0
# 229: train acc, test acc | 1.0, 1.0
# 230: train acc, test acc | 1.0, 1.0
# 231: train acc, test acc | 1.0, 1.0
# 232: train acc, test acc | 1.0, 1.0
# 233: train acc, test acc | 1.0, 1.0
# 234: train acc, test acc | 1.0, 1.0
# 235: train acc, test acc | 1.0, 1.0
# 236: train acc, test acc | 1.0, 1.0
# 237: train acc, test acc | 1.0, 1.0
# 238: train acc, test acc | 1.0, 1.0
# 239: train acc, test acc | 1.0, 1.0
# 240: train acc, test acc | 1.0, 1.0
# 241: train acc, test acc | 1.0, 1.0
# 242: train acc, test acc | 1.0, 1.0
# 243: train acc, test acc | 1.0, 1.0
# 244: train acc, test acc | 1.0, 1.0
# 245: train acc, test acc | 1.0, 1.0
# 246: train acc, test acc | 1.0, 1.0
# 247: train acc, test acc | 1.0, 1.0
# 248: train acc, test acc | 1.0, 1.0
# 249: train acc, test acc | 1.0, 1.0
# 250: train acc, test acc | 1.0, 1.0
# 251: train acc, test acc | 1.0, 1.0
# 252: train acc, test acc | 1.0, 1.0
# 253: train acc, test acc | 1.0, 1.0
# 254: train acc, test acc | 1.0, 1.0
# 255: train acc, test acc | 1.0, 1.0
# 256: train acc, test acc | 1.0, 1.0
# 257: train acc, test acc | 1.0, 1.0
# 258: train acc, test acc | 1.0, 1.0
# 259: train acc, test acc | 1.0, 1.0
# 260: train acc, test acc | 1.0, 1.0
# 261: train acc, test acc | 1.0, 1.0
# 262: train acc, test acc | 1.0, 1.0
# 263: train acc, test acc | 1.0, 1.0
# 264: train acc, test acc | 1.0, 1.0
# 265: train acc, test acc | 1.0, 1.0
# 266: train acc, test acc | 1.0, 1.0
# 267: train acc, test acc | 1.0, 1.0
# 268: train acc, test acc | 1.0, 1.0
# 269: train acc, test acc | 1.0, 1.0
# 270: train acc, test acc | 1.0, 1.0
# 271: train acc, test acc | 1.0, 1.0
# 272: train acc, test acc | 1.0, 1.0
# 273: train acc, test acc | 1.0, 1.0
# 274: train acc, test acc | 1.0, 1.0
# 275: train acc, test acc | 1.0, 1.0
# 276: train acc, test acc | 1.0, 1.0
# 277: train acc, test acc | 1.0, 1.0
# 278: train acc, test acc | 1.0, 1.0
# 279: train acc, test acc | 1.0, 1.0
# 280: train acc, test acc | 1.0, 1.0
# 281: train acc, test acc | 1.0, 1.0
# 282: train acc, test acc | 1.0, 1.0
# 283: train acc, test acc | 1.0, 1.0
# 284: train acc, test acc | 1.0, 1.0
# 285: train acc, test acc | 1.0, 1.0
# 286: train acc, test acc | 1.0, 1.0
# 287: train acc, test acc | 1.0, 1.0
# 288: train acc, test acc | 1.0, 1.0
# 289: train acc, test acc | 1.0, 1.0
# 290: train acc, test acc | 1.0, 1.0
# 291: train acc, test acc | 1.0, 1.0
# 292: train acc, test acc | 1.0, 1.0
# 293: train acc, test acc | 1.0, 1.0
# 294: train acc, test acc | 1.0, 1.0
# 295: train acc, test acc | 1.0, 1.0
# 296: train acc, test acc | 1.0, 1.0
# 297: train acc, test acc | 1.0, 1.0
# 298: train acc, test acc | 1.0, 1.0
# 299: train acc, test acc | 1.0, 1.0
# 300: train acc, test acc | 1.0, 1.0
# 301: train acc, test acc | 1.0, 1.0
# 302: train acc, test acc | 1.0, 1.0
# 303: train acc, test acc | 1.0, 1.0
# 304: train acc, test acc | 1.0, 1.0
# 305: train acc, test acc | 1.0, 1.0
# 306: train acc, test acc | 1.0, 1.0
# 307: train acc, test acc | 1.0, 1.0
# 308: train acc, test acc | 1.0, 1.0
# 309: train acc, test acc | 1.0, 1.0
# 310: train acc, test acc | 1.0, 1.0
# 311: train acc, test acc | 1.0, 1.0
# 312: train acc, test acc | 1.0, 1.0
# 313: train acc, test acc | 1.0, 1.0
# 314: train acc, test acc | 1.0, 1.0
# 315: train acc, test acc | 1.0, 1.0
# 316: train acc, test acc | 1.0, 1.0
# 317: train acc, test acc | 1.0, 1.0
# 318: train acc, test acc | 1.0, 1.0
# 319: train acc, test acc | 1.0, 1.0
# 320: train acc, test acc | 1.0, 1.0
# 321: train acc, test acc | 1.0, 1.0
# 322: train acc, test acc | 1.0, 1.0
# 323: train acc, test acc | 1.0, 1.0
# 324: train acc, test acc | 1.0, 1.0
# 325: train acc, test acc | 1.0, 1.0
# 326: train acc, test acc | 1.0, 1.0
# 327: train acc, test acc | 1.0, 1.0
# 328: train acc, test acc | 1.0, 1.0
# 329: train acc, test acc | 1.0, 1.0
# 330: train acc, test acc | 1.0, 1.0
# 331: train acc, test acc | 1.0, 1.0
# 332: train acc, test acc | 1.0, 1.0
# 333: train acc, test acc | 1.0, 1.0
# 334: train acc, test acc | 1.0, 1.0
# 335: train acc, test acc | 1.0, 1.0
# 336: train acc, test acc | 1.0, 1.0
# 337: train acc, test acc | 1.0, 1.0
# 338: train acc, test acc | 1.0, 1.0
# 339: train acc, test acc | 1.0, 1.0
# 340: train acc, test acc | 1.0, 1.0
# 341: train acc, test acc | 1.0, 1.0
# 342: train acc, test acc | 1.0, 1.0
# 343: train acc, test acc | 1.0, 1.0
# 344: train acc, test acc | 1.0, 1.0
# 345: train acc, test acc | 1.0, 1.0
# 346: train acc, test acc | 1.0, 1.0
# 347: train acc, test acc | 1.0, 1.0
# 348: train acc, test acc | 1.0, 1.0
# 349: train acc, test acc | 1.0, 1.0
# 350: train acc, test acc | 1.0, 1.0
# 351: train acc, test acc | 1.0, 1.0
# 352: train acc, test acc | 1.0, 1.0
# 353: train acc, test acc | 1.0, 1.0
# 354: train acc, test acc | 1.0, 1.0
# 355: train acc, test acc | 1.0, 1.0
# 356: train acc, test acc | 1.0, 1.0
# 357: train acc, test acc | 1.0, 1.0
# 358: train acc, test acc | 1.0, 1.0
# 359: train acc, test acc | 1.0, 1.0
# 360: train acc, test acc | 1.0, 1.0
# 361: train acc, test acc | 1.0, 1.0
# 362: train acc, test acc | 1.0, 1.0
# 363: train acc, test acc | 1.0, 1.0
# 364: train acc, test acc | 1.0, 1.0
# 365: train acc, test acc | 1.0, 1.0
# 366: train acc, test acc | 1.0, 1.0
# 367: train acc, test acc | 1.0, 1.0
# 368: train acc, test acc | 1.0, 1.0
# 369: train acc, test acc | 1.0, 1.0
# 370: train acc, test acc | 1.0, 1.0
# 371: train acc, test acc | 1.0, 1.0
# 372: train acc, test acc | 1.0, 1.0
# 373: train acc, test acc | 1.0, 1.0
# 374: train acc, test acc | 1.0, 1.0
# 375: train acc, test acc | 1.0, 1.0
# 376: train acc, test acc | 1.0, 1.0
# 377: train acc, test acc | 1.0, 1.0
# 378: train acc, test acc | 1.0, 1.0
# 379: train acc, test acc | 1.0, 1.0
# 380: train acc, test acc | 1.0, 1.0
# 381: train acc, test acc | 1.0, 1.0
# 382: train acc, test acc | 1.0, 1.0
# 383: train acc, test acc | 1.0, 1.0
# 384: train acc, test acc | 1.0, 1.0
# 385: train acc, test acc | 1.0, 1.0
# 386: train acc, test acc | 1.0, 1.0
# 387: train acc, test acc | 1.0, 1.0
# 388: train acc, test acc | 1.0, 1.0
# 389: train acc, test acc | 1.0, 1.0
# 390: train acc, test acc | 1.0, 1.0
# 391: train acc, test acc | 1.0, 1.0
# 392: train acc, test acc | 1.0, 1.0
# 393: train acc, test acc | 1.0, 1.0
# 394: train acc, test acc | 1.0, 1.0
# 395: train acc, test acc | 1.0, 1.0
# 396: train acc, test acc | 1.0, 1.0
# 397: train acc, test acc | 1.0, 1.0
# 398: train acc, test acc | 1.0, 1.0
# 399: train acc, test acc | 1.0, 1.0
# 400: train acc, test acc | 1.0, 1.0
# 401: train acc, test acc | 1.0, 1.0
# 402: train acc, test acc | 1.0, 1.0
# 403: train acc, test acc | 1.0, 1.0
# 404: train acc, test acc | 1.0, 1.0
# 405: train acc, test acc | 1.0, 1.0
# 406: train acc, test acc | 1.0, 1.0
# 407: train acc, test acc | 1.0, 1.0
# 408: train acc, test acc | 1.0, 1.0
# 409: train acc, test acc | 1.0, 1.0
# 410: train acc, test acc | 1.0, 1.0
# 411: train acc, test acc | 1.0, 1.0
# 412: train acc, test acc | 1.0, 1.0
# 413: train acc, test acc | 1.0, 1.0
# 414: train acc, test acc | 1.0, 1.0
# 415: train acc, test acc | 1.0, 1.0
# 416: train acc, test acc | 1.0, 1.0
# 417: train acc, test acc | 1.0, 1.0
# 418: train acc, test acc | 1.0, 1.0
# 419: train acc, test acc | 1.0, 1.0
# 420: train acc, test acc | 1.0, 1.0
# 421: train acc, test acc | 1.0, 1.0
# 422: train acc, test acc | 1.0, 1.0
# 423: train acc, test acc | 1.0, 1.0
# 424: train acc, test acc | 1.0, 1.0
# 425: train acc, test acc | 1.0, 1.0
# 426: train acc, test acc | 1.0, 1.0
# 427: train acc, test acc | 1.0, 1.0
# 428: train acc, test acc | 1.0, 1.0
# 429: train acc, test acc | 1.0, 1.0
# 430: train acc, test acc | 1.0, 1.0
# 431: train acc, test acc | 1.0, 1.0
# 432: train acc, test acc | 1.0, 1.0
# 433: train acc, test acc | 1.0, 1.0
# 434: train acc, test acc | 1.0, 1.0
# 435: train acc, test acc | 1.0, 1.0
# 436: train acc, test acc | 1.0, 1.0
# 437: train acc, test acc | 1.0, 1.0
# 438: train acc, test acc | 1.0, 1.0
# 439: train acc, test acc | 1.0, 1.0
# 440: train acc, test acc | 1.0, 1.0
# 441: train acc, test acc | 1.0, 1.0
# 442: train acc, test acc | 1.0, 1.0
# 443: train acc, test acc | 1.0, 1.0
# 444: train acc, test acc | 1.0, 1.0
# 445: train acc, test acc | 1.0, 1.0
# 446: train acc, test acc | 1.0, 1.0
# 447: train acc, test acc | 1.0, 1.0
# 448: train acc, test acc | 1.0, 1.0
# 449: train acc, test acc | 1.0, 1.0
# 450: train acc, test acc | 1.0, 1.0
# 451: train acc, test acc | 1.0, 1.0
# 452: train acc, test acc | 1.0, 1.0
# 453: train acc, test acc | 1.0, 1.0
# 454: train acc, test acc | 1.0, 1.0
# 455: train acc, test acc | 1.0, 1.0
# 456: train acc, test acc | 1.0, 1.0
# 457: train acc, test acc | 1.0, 1.0
# 458: train acc, test acc | 1.0, 1.0
# 459: train acc, test acc | 1.0, 1.0
# 460: train acc, test acc | 1.0, 1.0
# 461: train acc, test acc | 1.0, 1.0
# 462: train acc, test acc | 1.0, 1.0
# 463: train acc, test acc | 1.0, 1.0
# 464: train acc, test acc | 1.0, 1.0
# 465: train acc, test acc | 1.0, 1.0
# 466: train acc, test acc | 1.0, 1.0
# 467: train acc, test acc | 1.0, 1.0
# 468: train acc, test acc | 1.0, 1.0
# 469: train acc, test acc | 1.0, 1.0
# 470: train acc, test acc | 1.0, 1.0
# 471: train acc, test acc | 1.0, 1.0
# 472: train acc, test acc | 1.0, 1.0
# 473: train acc, test acc | 1.0, 1.0
# 474: train acc, test acc | 1.0, 1.0
# 475: train acc, test acc | 1.0, 1.0
# 476: train acc, test acc | 1.0, 1.0
# 477: train acc, test acc | 1.0, 1.0
# 478: train acc, test acc | 1.0, 1.0
# 479: train acc, test acc | 1.0, 1.0
# 480: train acc, test acc | 1.0, 1.0
# 481: train acc, test acc | 1.0, 1.0
# 482: train acc, test acc | 1.0, 1.0
# 483: train acc, test acc | 1.0, 1.0
# 484: train acc, test acc | 1.0, 1.0
# 485: train acc, test acc | 1.0, 1.0
# 486: train acc, test acc | 1.0, 1.0
# 487: train acc, test acc | 1.0, 1.0
# 488: train acc, test acc | 1.0, 1.0
# 489: train acc, test acc | 1.0, 1.0
# 490: train acc, test acc | 1.0, 1.0
# 491: train acc, test acc | 1.0, 1.0
# 492: train acc, test acc | 1.0, 1.0
# 493: train acc, test acc | 1.0, 1.0
# 494: train acc, test acc | 1.0, 1.0
# 495: train acc, test acc | 1.0, 1.0
# 496: train acc, test acc | 1.0, 1.0
# 497: train acc, test acc | 1.0, 1.0
# 498: train acc, test acc | 1.0, 1.0
# 499: train acc, test acc | 1.0, 1.0

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# 그림 4-11 손실 함수의 추이: 위쪽은 500회 반복까지의 추이, 아래쪽은 1,00회 반복까지의 추이
f, (ax1, ax2) = plt.subplots(2, 1)
x = np.array(range(iters_num))
ax1.plot(x, train_loss_list, label='loss')
ax1.set_xlabel("iteration")
ax1.set_ylabel("loss")
# ax1.set_ylim(0, 3.0)
ax2.plot(x[:100], train_loss_list[:100], label='loss')
ax2.set_xlabel("iteration")
ax2.set_ylabel("loss")
# ax2.set_ylim(0, 3.0)
# Out:
# Text(0, 0.5, 'loss')

# %%
# for param in net.params["W1"]:
#   print(param)
param_W1 = []
for param in network.params["W1"]:
    param_W1.append(param)
print(len(param_W1))
print(network.params["W1"].shape)
f = open("param_α.txt","w", encoding='UTF-8', newline='')
f.write("Params of α, Shape of α: %s\n\n" %str(network.params["W1"].shape))
for num in range(0,len(param_W1)):
    f.write("%s\n" %param_W1[num])
f.close
# Out:
# 784
# (784, 1)
# <function TextIOWrapper.close()>

# %%
# for param in net.params["W1"]:
#   print(param)
param_b1 = []
for param in network.params["b1"]:
    param_W1.append(param)
print(len(param_b1))
print(network.params["b1"].shape)
f = open("param_β.txt","w", encoding='UTF-8', newline='')
f.write("Params of β, Shape of β: %s\n\n" %str(network.params["b1"].shape))
for num in range(0,len(param_W1)):
    f.write("%s\n" %param_W1[num])
f.close
# Out:
# 0
# (1,)
# <function TextIOWrapper.close()>
